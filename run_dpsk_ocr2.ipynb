# %%
CUDA_VISIBLE_DEVICES=1 \
# !python deepseek_ocr2_runner.py \
    --deepseek_repo /content/drive/MyDrive/PingAn/OCR Extraction/DeepSeek-OCR-2/DeepSeek-OCR2-master \
    --model_path /content/drive/MyDrive/PingAn/OCR Extraction/model_cache/DeepSeek-OCR-2 \
    --prompt "\n<|grounding|>Convert the document to markdown." \
    --crop_mode 1 \
    jsonl \
    --input_jsonl /content/drive/MyDrive/PingAn/OCR Extraction/a_li_yun_medical_test.jsonl \
    --output_jsonl ocr_extract/dpsk_ocr2_ocr_extract_results.jsonl

# %%
CUDA_VISIBLE_DEVICES=1 \
# !python dpsk_ocr2_runner.py \
    --deepseek_repo /content/drive/MyDrive/PingAn/OCR Extraction/DeepSeek-OCR-2/DeepSeek-OCR2-master \
    --model_path /content/drive/MyDrive/PingAn/OCR Extraction/model_cache/DeepSeek-OCR-2 \
    --prompt "\n<|grounding|>Convert the document to markdown." \
    --crop_mode 1 \
    single \
    --image /content/drive/MyDrive/PingAn/OCR Extraction/sample_imgs/27de47bb9d9f4d4a95b55b16b08a7528_5.png \
    --save_txt /tmp/45f04ade2e_10.ocr.txt
    # --image /data/diaoliang/vvw/projects/ms-swift-3.9.0/scripts/a_li_yun_medical/a_li_yun_medical_dataset/test_imgs/45f04ade2e_10.jpg \
